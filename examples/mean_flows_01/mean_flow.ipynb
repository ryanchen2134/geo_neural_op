# %%
import torch
import numpy as np
import os
from pathlib import Path
import pyvista as pv

if Path.cwd().as_posix().endswith('/mean_flows_01'):
    os.chdir('../..')
from gnp.estimator import GeometryEstimator

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f"Using {device}")

pv.set_jupyter_backend("static")
# Out:
# Using cuda

# %%
def get_data(data_name, noise_level=0.0, noise_ratio=0.0):
    data_path = os.path.join('example_data', data_name)
    data = {}
    for file in os.listdir(data_path):
        if file.endswith('.npy'):
            data[file[:-4]] = torch.from_numpy(np.load(os.path.join(data_path, file))).to(device)
    if noise_level > 0.0 and noise_ratio > 0.0:
        xyz = data['xyz']
        noise_inds = torch.randperm(xyz.shape[0])[:int(noise_ratio*xyz.shape[0])]
        noise = torch.randn_like(xyz[noise_inds]) * noise_level
        xyz[noise_inds] += noise
        data['xyz'] = xyz
    return data

# %%
file = 'spot'

data_clean = get_data(file)
estimator_clean = GeometryEstimator(data_clean['xyz'], 
                              orientation=data_clean['normals'], 
                              device=device)

# %%
estimator_clean.pcd.shape
# Out:
# torch.Size([97876, 3])

# %%
flow_data = estimator_clean.mean_flow(num_steps=1601, 
                                      save_data_per_step=200,
                                      delta_t=0.0002,
                                      subsample_radius=0.005,
                                      smooth_radius=0.06,
                                      smooth_x=False)
# Out:
#   4%|▍         | 70/1601 [02:17<50:02,  1.96s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 flow_data = estimator_clean.mean_flow(num_steps=1601,
#       2                                       save_data_per_step=200,
#       3                                       delta_t=0.0002,
#       4                                       subsample_radius=0.005,
#
# File ~/geo_neural_op/gnp/estimator.py:253, in GeometryEstimator.mean_flow(self, num_steps, save_data_per_step, delta_t, subsample_radius, smooth_radius, smooth_x)
#     251 save_data = []
#     252 for i in tqdm(range(num_steps)):
# --> 253     new_data = self.flow_step(
#     254         delta_t=delta_t,
#     255         subsample_radius=subsample_radius,
#     256         smooth_radius=smooth_radius,
#     257         smooth_x=smooth_x,
#     258     )
#     259     self.data = new_data.copy()
#     260     self.pcd = new_data["x"]
#
# File ~/geo_neural_op/gnp/estimator.py:193, in GeometryEstimator.flow_step(self, delta_t, subsample_radius, smooth_radius, smooth_x)
#     190     self.pcd = x
#     191     self.data["x"] = x
# --> 193 estimate = self.estimate_quantities(["normals", "mean_curvature"])
#     194 x = self.pcd
#     195 normals = estimate["normals"]
#
# File ~/geo_neural_op/gnp/estimator.py:150, in GeometryEstimator.estimate_quantities(self, quantity_names)
#     128 def estimate_quantities(self, quantity_names: list[str]) -> dict[str, torch.Tensor]:
#     129     """
#     130     Estimate geometric quantities on the point cloud. This function returns
#     131     a dictionary containing the estimated scalar and/or vector values.
#    (...)    147         estimated tensors.
#     148     """
# --> 150     surface = self.surface_patch()
#     152     output = {}
#     153     for name in quantity_names:
#
# File ~/geo_neural_op/gnp/estimator.py:120, in GeometryEstimator.surface_patch(self, patch_data)
#     104 """
#     105 Create a Surface from the input patch data using the predictions from
#     106 the model.
#    (...)    117     Surface object.
#     118 """
#     119 if patch_data is None:
# --> 120     patch_data = self.patch_data()
#     121 surface_coefficients = []
#     122 for pd in patch_data.batch_iterator(self.batch_size):
#
# File ~/geo_neural_op/gnp/estimator.py:99, in GeometryEstimator.patch_data(self, **datakwargs)
#      97 for k, v in datakwargs.items():
#      98     data_config[k] = v
# ---> 99 return PatchTensor(
#     100     data=self.data, device=self.device, **data_config
#     101 ).as_patch_data()
#
# File ~/geo_neural_op/gnp/dataset/patch.py:139, in PatchTensor.__init__(self, data, k, mode, pca, scale, min_z_scale, basis, basis_degree, num_training_patches, device)
#     136 self.device = device
#     138 self.query = QueryTorchGeometric(x=self.x, device=self.device)
# --> 139 self.center_indices, self.clusters, self.knn_distances = self.get_centers()
#     140 self.patch_indices, self.patch_number, self.patch_lens = (
#     141     self._patch_data_query()
#     142 )
#     143 self.centers = scatter_mean(
#     144     self.x[self.patch_indices], index=self.patch_number, dim=0
#     145 )
#
# File ~/geo_neural_op/gnp/dataset/patch.py:162, in PatchTensor.get_centers(self)
#     160     return self.get_train_centers()
#     161 elif self.mode == "test":
# --> 162     return self.get_test_centers()
#     163 elif self.mode == "gmls":
#     164     return self.get_gmls_centers()
#
# File ~/geo_neural_op/gnp/dataset/patch.py:200, in PatchTensor.get_test_centers(self)
#     187 def get_test_centers(self) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
#     188     """
#     189     Select patch centers using a greedy covering strategy for testing.
#     190
#    (...)    198         Center indices, cluster assignments, and k-NN distances.
#     199     """
# --> 200     distances, ind = self.query.query_knn(self.x, k=self.k)
#     201     center_knn_ind = ind[:, : int(0.66 * self.k)].contiguous()
#     203     center_indices = []
#
# File ~/geo_neural_op/gnp/utils.py:48, in QueryTorchGeometric.query_knn(self, queries, k)
#      46 if not queries.device == self.device:
#      47     queries = queries.to(self.device)
# ---> 48 index_y, index_x = tg.nn.knn(self.x, queries, k=k)
#      49 distances = (self.x[index_x.view(-1, k)] - queries[index_y.view(-1, k)]).norm(
#      50     dim=-1
#      51 )
#      53 return distances, index_x.view(-1, k)
#
# File ~/anaconda3/envs/gnp/lib/python3.12/site-packages/torch_geometric/nn/pool/__init__.py:117, in knn(x, y, k, batch_x, batch_y, cosine, num_workers, batch_size)
#     114 if not torch_geometric.typing.WITH_TORCH_CLUSTER_BATCH_SIZE:
#     115     return torch_cluster.knn(x, y, k, batch_x, batch_y, cosine,
#     116                              num_workers)
# --> 117 return torch_cluster.knn(x, y, k, batch_x, batch_y, cosine, num_workers,
#     118                          batch_size)
#
# File ~/anaconda3/envs/gnp/lib/python3.12/site-packages/torch_cluster/knn.py:81, in knn(x, y, k, batch_x, batch_y, cosine, num_workers, batch_size)
#      78     ptr_x = torch.bucketize(arange, batch_x)
#      79     ptr_y = torch.bucketize(arange, batch_y)
# ---> 81 return torch.ops.torch_cluster.knn(x, y, ptr_x, ptr_y, k, cosine,
#      82                                    num_workers)
#
# File ~/anaconda3/envs/gnp/lib/python3.12/site-packages/torch/_ops.py:1255, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1253 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1254     return _call_overload_packet_from_python(self, *args, **kwargs)
# -> 1255 return self._op(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
camera_pos = [(-5.515810949058437, 1.6733713203173721, -2.9265943826878433),
              (6.279349327087402e-05, 0.2162138819694519, 0.029896080493927002),
              (0.19613395058580294, 0.9739175157878064, 0.11408832485979425)]
steps = [0, 2, 4, 8]
plotter = pv.Plotter(shape=(1, len(steps)), window_size=(1600, 400))
window = 0
for i, step in enumerate(flow_data):
    if i not in steps:
        continue
    poly_data = pv.PolyData(step['x'].cpu().numpy())
    poly_data['mean_curvature'] = step['mean_curvature'].cpu().numpy()
    
    plotter.subplot(0, window)
    plotter.add_points(poly_data, 
                       style='points', 
                       point_size=8, 
                       render_points_as_spheres=True,
                       cmap='coolwarm',
                       scalars='mean_curvature', 
                       clim=[-5, 5],
                       copy_mesh=True)
    plotter.add_text(f'Step {200*i}', font_size=10)
    plotter.camera_position = camera_pos
    plotter.camera.zoom(1)
    plotter.remove_scalar_bar()
    window += 1
plotter.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       3               (0.19613395058580294, 0.9739175157878064, 0.11408832485979425)]
#       4 steps = [0, 2, 4, 8]
#       5 plotter = pv.Plotter(shape=(1, len(steps)), window_size=(1600, 400))
#       6 window = 0
# ----> 7 for i, step in enumerate(flow_data):
#       8     if i not in steps:
#       9         continue
#      10     poly_data = pv.PolyData(step['x'].cpu().numpy())
#
# NameError: name 'flow_data' is not defined
